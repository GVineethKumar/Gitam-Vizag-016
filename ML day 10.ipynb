# %% [markdown]
# ### Pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '0.25.1'

# %% [markdown]
# - series --> 1d array
# - Dataframe --> 2d array
# - Pannel --> 3d array

# %%
pd.Series([56,12,40,90])
# Out:
# 0    56
# 1    12
# 2    40
# 3    90
# dtype: int64

# %%
pd.Series([56,12,40,90],index=['r','j','b','v'])
# Out:
# r    56
# j    12
# b    40
# v    90
# dtype: int64

# %%
g = pd.Series([56,12,40,90],index=['r','j','b','v'])
print(g['r'],g[0])
# Out:
# 56 56

# %%
import numpy as np
np.array([56,12,40,90])
# Out:
# array([56, 12, 40, 90])

# %%
d = {'a':12,'b':13,'c':14,'d':15,'e':16}
pd.Series(d)
# Out:
# a    12
# b    13
# c    14
# d    15
# e    16
# dtype: int64

# %%
# to access the indices of a series using the index attribute
g.index
# Out:
# Index(['r', 'j', 'b', 'v'], dtype='object')

# %% [markdown]
# ### Dataframe

# %%
d2 = {'name':['vineeth','jagan','ravi'],
     'language':['py','c','R']}
pd.DataFrame(d2)
# Out:
#       name language
# 0  vineeth       py
# 1    jagan        c
# 2     ravi        R

# %%
data = pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.csv')
data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
data.head(5)
# Out:
#              Timestamp              Name                            MailId  \
# 0  30/01/2020 15:00:07     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 1  30/01/2020 15:00:20          R deepak            deepakrella9@gmail.com
# 2  30/01/2020 15:00:23     P K CHAITANYA              chaitu1495@gmail.com
# 3  30/01/2020 15:00:25        B SRIKANTH           srikanthbisai@gmail.com
# 4  30/01/2020 15:00:28  Himaja cherukuri         himajacherukuri@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 1    MCA            PG  121722501019
# 2    MCA            PG  121722501015
# 3    MCA            PG  121722501002
# 4    cse         BTech    161fa04079

# %%
# To check the no.of rows and columns
data.shape
# Out:
# (26, 6)

# %%
data['Name']
# Out:
# 0                 Sai Naga Raju
# 1                      R deepak
# 2                 P K CHAITANYA
# 3                    B SRIKANTH
# 4              Himaja cherukuri
# 5                 M.Geethanjali
# 6                     M.Nikhita
# 7              DASARI PAVAN SAI
# 8                 B Jagan Mohan
# 9             k.parameswara rao
# 10             B.Ravindra kumar
# 11          P.M.S.Bhargav Kumar
# 12        Thatavarti kavya sree
# 13                 Harish Bandi
# 14       M.Bhavani Sankar Reddy
# 15               Devendra Kumar
# 16                      M.Ramya
# 17              T.V.Naga Jyothi
# 18               Ananda Lakshmi
# 19                  K . krishna
# 20         Md.Ali Asghar Khoyee
# 21             G. Vineeth Kumar
# 22    JAYA NAVEEN KUMAR DUPPATI
# 23                     vikram S
# 24              SAI TEJA JALADI
# 25           SAIKUMAR MANIKONDA
# Name: Name, dtype: object

# %%
data[['Name','MailId']]
# Out:
#                          Name                            MailId
# 0               Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 1                    R deepak            deepakrella9@gmail.com
# 2               P K CHAITANYA              chaitu1495@gmail.com
# 3                  B SRIKANTH           srikanthbisai@gmail.com
# 4            Himaja cherukuri         himajacherukuri@gmail.com
# 5               M.Geethanjali           geethamuppuri@gmail.com
# 6                   M.Nikhita            muvvanikhita@gmail.com
# 7            DASARI PAVAN SAI          pavandasari226@gmail.com
# 8               B Jagan Mohan           bjaganmohan24@gmail.com
# 9           k.parameswara rao    parameshkarumuri1997@gmail.com
# 10           B.Ravindra kumar    ravindrakumarroyal12@gmail.com
# 11        P.M.S.Bhargav Kumar     bhargavperumalla123@gmail.com
# 12      Thatavarti kavya sree         kavyathatavarti@gmail.com
# 13               Harish Bandi           harishbandi12@gmail.com
# ...

# %%
data.sample()
# Out:
#               Timestamp              Name                 MailId  \
# 21  30/01/2020 15:02:41  G. Vineeth Kumar  121822502016@gitam.in
#
#           Branch Qualification    RollNumber
# 21  Data Science          M.Sc  121822502016

# %%
# Total no of rows 
data.shape[0]
# Out:
# 26

# %% [markdown]
# ### Task : Write a function for email validator

# %%
# to get the columns names
data.columns
# Out:
# Index(['Timestamp', 'Name', 'MailId', 'Branch', 'Qualification', 'RollNumber'], dtype='object')

# %%
# To get the row labels
data.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
# To check the dtypes of all columns
# output type - Series
data.dtypes
# Out:
# Timestamp        object
# Name             object
# MailId           object
# Branch           object
# Qualification    object
# RollNumber       object
# dtype: object

# %%
data.isnull()
# Out:
#     Timestamp   Name  MailId  Branch  Qualification  RollNumber
# 0       False  False   False   False          False       False
# 1       False  False   False   False          False       False
# 2       False  False   False   False          False       False
# 3       False  False   False   False          False       False
# 4       False  False   False   False          False       False
# 5       False  False   False   False          False       False
# 6       False  False   False   False          False       False
# 7       False  False   False   False          False       False
# 8       False  False   False   False          False       False
# 9       False  False   False   False          False       False
# 10      False  False   False   False          False       False
# 11      False  False   False   False          False       False
# 12      False  False   False   False          False       False
# 13      False  False   False   False          False       False
# ...

# %%
data.isnull().sum() # missing values count columnwise
# Out:
# Timestamp        0
# Name             0
# MailId           0
# Branch           0
# Qualification    0
# RollNumber       0
# dtype: int64

# %%
data.isnull().sum().sum() # missing value count in the dataframe
# Out:
# 0

# %%
data2 = pd.read_csv('ml student data.tsv','\t')
data2
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %% [markdown]
# ### Slicling

# %%
data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-80a4aab09c73> in <module>
# ----> 1 data[0]
#
# ...

# %% [markdown]
# - position based indexing --> iloc
# - label Based Indexing

# %%
data.iloc[0]
# Out:
# Timestamp                     30/01/2020 15:00:07
# Name                                Sai Naga Raju
# MailId           sainagarajusakhamuri99@gmail.com
# Branch                                         IT
# Qualification                              B.Tech
# RollNumber                             161FA07039
# Name: 0, dtype: object

# %%
data.iloc[0:1]
# Out:
#              Timestamp           Name                            MailId  \
# 0  30/01/2020 15:00:07  Sai Naga Raju  sainagarajusakhamuri99@gmail.com
#
#   Branch Qualification  RollNumber
# 0     IT        B.Tech  161FA07039

# %%
data.iloc[0:6:2]
# Out:
#              Timestamp              Name                            MailId  \
# 0  30/01/2020 15:00:07     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2  30/01/2020 15:00:23     P K CHAITANYA              chaitu1495@gmail.com
# 4  30/01/2020 15:00:28  Himaja cherukuri         himajacherukuri@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 2    MCA            PG  121722501015
# 4    cse         BTech    161fa04079

# %%
data.iloc[0:6:2,1:3]
# Out:
#                Name                            MailId
# 0     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2     P K CHAITANYA              chaitu1495@gmail.com
# 4  Himaja cherukuri         himajacherukuri@gmail.com

# %%
data.iloc[-2:,-2:]
# Out:
#    Qualification    RollNumber
# 24        B.TECH    161FA07025
# 25           B.E  245112769310

# %%
data.loc[0]
# Out:
# Timestamp                     30/01/2020 15:00:07
# Name                                Sai Naga Raju
# MailId           sainagarajusakhamuri99@gmail.com
# Branch                                         IT
# Qualification                              B.Tech
# RollNumber                             161FA07039
# Name: 0, dtype: object

# %%
data.loc[0:1]
# Out:
#              Timestamp           Name                            MailId  \
# 0  30/01/2020 15:00:07  Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 1  30/01/2020 15:00:20       R deepak            deepakrella9@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 1    MCA            PG  121722501019

# %%
data.loc[0:6:2]
# Out:
#              Timestamp              Name                            MailId  \
# 0  30/01/2020 15:00:07     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2  30/01/2020 15:00:23     P K CHAITANYA              chaitu1495@gmail.com
# 4  30/01/2020 15:00:28  Himaja cherukuri         himajacherukuri@gmail.com
# 6  30/01/2020 15:00:33         M.Nikhita            muvvanikhita@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 2    MCA            PG  121722501015
# 4    cse         BTech    161fa04079
# 6    CSE        B.Tech    161FA04106

# %%
data.loc[0:4:2,'Name':'MailId']
# Out:
#                Name                            MailId
# 0     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2     P K CHAITANYA              chaitu1495@gmail.com
# 4  Himaja cherukuri         himajacherukuri@gmail.com

# %%
data.loc[7:16:4,'Branch':'RollNumber']
# Out:
#                     Branch Qualification    RollNumber
# 7   Information Technology        B.Tech    161FA07042
# 11        Computer Science           MCA  121722501026
# 15                     ECE        B.Tech    14F41A0461

# %%
data.loc[25:23:-1,'Qualification':'RollNumber']
# Out:
#    Qualification    RollNumber
# 25           B.E  245112769310
# 24        B.TECH    161FA07025
# 23        B-tech    133J1A0150
