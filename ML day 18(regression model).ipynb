# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sales_data = pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Intel%20Data/Ames_Housing_Sales.csv')
sales_data
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0        856.0     854.0        0.0  None             3     1Fam       TA
# 1       1262.0       0.0        0.0  None             3     1Fam       TA
# 2        920.0     866.0        0.0  None             3     1Fam       TA
# 3        961.0     756.0        0.0  None             3     1Fam       Gd
# 4       1145.0    1053.0        0.0  None             4     1Fam       TA
# ...        ...       ...        ...   ...           ...      ...      ...
# 1374     953.0     694.0        0.0  None             3     1Fam     None
# 1375    2073.0       0.0        0.0  None             3     1Fam       TA
# 1376    1188.0    1152.0        0.0  None             4     1Fam       Gd
# 1377    1078.0       0.0        0.0  None             2     1Fam       TA
# 1378    1256.0       0.0        0.0  None             3     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2  ... ScreenPorch Street  \
# ...

# %%
sales_data.shape[1]
# Out:
# 80

# %%
sales_data.columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley', 'BedroomAbvGr',
#        'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath',
#        'BsmtQual', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'EnclosedPorch', 'ExterCond', 'ExterQual', 'Exterior1st',
#        'Exterior2nd', 'Fence', 'FireplaceQu', 'Fireplaces', 'Foundation',
#        'FullBath', 'Functional', 'GarageArea', 'GarageCars', 'GarageCond',
#        'GarageFinish', 'GarageQual', 'GarageType', 'GarageYrBlt', 'GrLivArea',
#        'HalfBath', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenAbvGr',
#        'KitchenQual', 'LandContour', 'LandSlope', 'LotArea', 'LotConfig',
#        'LotFrontage', 'LotShape', 'LowQualFinSF', 'MSSubClass', 'MSZoning',
#        'MasVnrArea', 'MasVnrType', 'MiscFeature', 'MiscVal', 'MoSold',
#        'Neighborhood', 'OpenPorchSF', 'OverallCond', 'OverallQual',
# ...

# %%
sales_data.dtypes
# Out:
# 1stFlrSF        float64
# 2ndFlrSF        float64
# 3SsnPorch       float64
# Alley            object
# BedroomAbvGr      int64
#                  ...
# WoodDeckSF      float64
# YearBuilt         int64
# YearRemodAdd      int64
# YrSold            int64
# SalePrice       float64
# Length: 80, dtype: object

# %%
int_count = sales_data.columns[sales_data.dtypes == np.int64]
int_count.value_counts().sum()
# Out:
# 16

# %%
float_count = sales_data.columns[sales_data.dtypes == np.float64]
float_count.value_counts().sum()
# Out:
# 21

# %%
obj_count = sales_data.columns[sales_data.dtypes == np.object]
obj_count.value_counts().sum()
# Out:
# 43

# %%
cat_cols = sales_data.columns[sales_data.dtypes == 'object']
cat_cols
# Out:
# Index(['Alley', 'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'BsmtQual', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd',
#        'Fence', 'FireplaceQu', 'Foundation', 'Functional', 'GarageCond',
#        'GarageFinish', 'GarageQual', 'GarageType', 'Heating', 'HeatingQC',
#        'HouseStyle', 'KitchenQual', 'LandContour', 'LandSlope', 'LotConfig',
#        'LotShape', 'MSZoning', 'MasVnrType', 'MiscFeature', 'Neighborhood',
#        'PavedDrive', 'PoolQC', 'RoofMatl', 'RoofStyle', 'SaleCondition',
#        'SaleType', 'Street', 'Utilities'],
#       dtype='object')

# %%
feature = sales_data.drop('SalePrice',axis=1)
target = sales_data['SalePrice']

# %%
num_cols = feature.columns[feature.dtypes != 'object']
num_cols
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF',
#        'EnclosedPorch', 'Fireplaces', 'FullBath', 'GarageArea', 'GarageCars',
#        'GarageYrBlt', 'GrLivArea', 'HalfBath', 'KitchenAbvGr', 'LotArea',
#        'LotFrontage', 'LowQualFinSF', 'MSSubClass', 'MasVnrArea', 'MiscVal',
#        'MoSold', 'OpenPorchSF', 'OverallCond', 'OverallQual', 'PoolArea',
#        'ScreenPorch', 'TotRmsAbvGrd', 'TotalBsmtSF', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object')

# %%
feature[num_cols]
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 0        856.0     854.0        0.0             3       706.0         0.0
# 1       1262.0       0.0        0.0             3       978.0         0.0
# 2        920.0     866.0        0.0             3       486.0         0.0
# 3        961.0     756.0        0.0             3       216.0         0.0
# 4       1145.0    1053.0        0.0             4       655.0         0.0
# ...        ...       ...        ...           ...         ...         ...
# 1374     953.0     694.0        0.0             3         0.0         0.0
# 1375    2073.0       0.0        0.0             3       790.0       163.0
# 1376    1188.0    1152.0        0.0             4       275.0         0.0
# 1377    1078.0       0.0        0.0             2        49.0      1029.0
# 1378    1256.0       0.0        0.0             3       830.0       290.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  ...  OverallCond  \
# ...

# %%
a = pd.DataFrame(feature[num_cols])
a.shape
# Out:
# (1379, 36)

# %%
feature[num_cols].describe()
# Out:
#           1stFlrSF     2ndFlrSF    3SsnPorch  BedroomAbvGr   BsmtFinSF1  \
# count  1379.000000  1379.000000  1379.000000   1379.000000  1379.000000
# mean   1177.129804   353.424946     3.609862      2.865120   455.578680
# std     387.014961   439.553171    30.154682      0.783961   459.691379
# min     438.000000     0.000000     0.000000      0.000000     0.000000
# 25%     894.000000     0.000000     0.000000      2.000000     0.000000
# 50%    1098.000000     0.000000     0.000000      3.000000   400.000000
# 75%    1414.000000   738.500000     0.000000      3.000000   732.000000
# max    4692.000000  2065.000000   508.000000      6.000000  5644.000000
#
#         BsmtFinSF2  BsmtFullBath  BsmtHalfBath    BsmtUnfSF  EnclosedPorch  \
# count  1379.000000   1379.000000   1379.000000  1379.000000    1379.000000
# mean     48.102248      0.430747      0.058738   570.765047      21.039159
# std     164.324665      0.514052      0.238285   443.677845      60.535107
# ...

# %%
plt.hist(target)
# Out:
# (array([105., 692., 367., 134.,  52.,  18.,   4.,   3.,   2.,   2.]),
#  array([ 35311. , 107279.9, 179248.8, 251217.7, 323186.6, 395155.5,
#         467124.4, 539093.3, 611062.2, 683031.1, 755000. ]),
#  <a list of 10 Patch objects>)

# %%
plt.figure(figsize=(10,300))
plt.subplots_adjust(hspace=1)
for i in range(len(num_cols)):
    plt.subplot(80,2,2*i + 1)
    plt.hist(feature[num_cols[i]])
    plt.title(num_cols[i]+' Histogram')
    plt.subplot(80,2,2*i+2)
    plt.boxplot(feature[num_cols[i]])
